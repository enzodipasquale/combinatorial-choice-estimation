# %%
import numpy as np

S = 2
N = 3
comm_size = 2
rank = 4
print(S*N)

print(np.arange(rank, S * N, comm_size))
# Out:
# 6
# [4]

# %%
if np.arange(6).reshape(1,6).shape[1:]:
    print("True")
# Out:
# True

# %%
np.prod((2))
# Out:
# 2

# %%
(1,)+()
# Out:
# (1,)
